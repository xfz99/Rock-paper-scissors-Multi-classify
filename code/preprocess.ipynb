# %%
import cv2
import numpy as np
from skimage import transform
import matplotlib.pyplot as plt
from skimage import transform
import picture as pic

import numpy as np

# %%
imgpath='C:/Users/Administrator/shiyan/rps-test-set/rock'
import os
imgs= os.listdir(imgpath) #得到文件夹下的所有文件名称
for img in imgs:
    path=imgpath+'/'+img
    print(path)
    image = cv2.imread(path)
    cv2.imshow("i",image)
    width, height = 300, 300  # 设置拍摄窗口大小
    x0, y0 = 0,0  # 设置选取位置

    roi, res, ret = pic.binaryMask(image, x0, y0, width, height)

    filepath=imgpath+'/new'+img

    cv2.imwrite(filepath, ret)
# Out:
# C:/Users/Administrator/shiyan/rps-test-set/rock/testrock01-00.png
# C:/Users/Administrator/shiyan/rps-test-set/rock/testrock01-01.png
# C:/Users/Administrator/shiyan/rps-test-set/rock/testrock01-02.png
# C:/Users/Administrator/shiyan/rps-test-set/rock/testrock01-03.png
# C:/Users/Administrator/shiyan/rps-test-set/rock/testrock01-04.png
# C:/Users/Administrator/shiyan/rps-test-set/rock/testrock01-05.png
# C:/Users/Administrator/shiyan/rps-test-set/rock/testrock01-06.png
# C:/Users/Administrator/shiyan/rps-test-set/rock/testrock01-07.png
# C:/Users/Administrator/shiyan/rps-test-set/rock/testrock01-08.png
# C:/Users/Administrator/shiyan/rps-test-set/rock/testrock01-09.png
# C:/Users/Administrator/shiyan/rps-test-set/rock/testrock01-10.png
# C:/Users/Administrator/shiyan/rps-test-set/rock/testrock01-11.png
# C:/Users/Administrator/shiyan/rps-test-set/rock/testrock01-12.png
# C:/Users/Administrator/shiyan/rps-test-set/rock/testrock01-13.png
# ...
